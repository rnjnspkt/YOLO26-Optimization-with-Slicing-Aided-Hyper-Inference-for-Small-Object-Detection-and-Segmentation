# %%
import numpy as np
print(np.__version__)
# Out:
# 1.26.4

# %%
# !pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -cipy (/home/ranjan/.local/lib/python3.10/site-packages)
# ...
# WARNING: Ignoring invalid distribution -cipy (/home/ranjan/.local/lib/python3.10/site-packages)
# WARNING: Error parsing dependencies of send2trash: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     sys-platform (=="darwin") ; extra == 'objc'
#                  ~^
# WARNING: Error parsing dependencies of flatbuffers: Invalid version: '1.12.1-git20200711.33e2d80-dfsg1-0.6'
# WARNING: Ignoring invalid distribution -cipy (/home/ranjan/.local/lib/python3.10/site-packages)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import torch
import numpy as np

print("Torch:", torch.__version__)
print("NumPy:", np.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# Torch: 2.1.0+cu121
# NumPy: 1.26.4
# CUDA available: True

# %%
torch.cuda.get_device_name(0)
# !pip install numpy==1.26.4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -cipy (/home/ranjan/.local/lib/python3.10/site-packages)
# ...
# WARNING: Ignoring invalid distribution -cipy (/home/ranjan/.local/lib/python3.10/site-packages)
# WARNING: Error parsing dependencies of send2trash: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     sys-platform (=="darwin") ; extra == 'objc'
#                  ~^
# WARNING: Error parsing dependencies of flatbuffers: Invalid version: '1.12.1-git20200711.33e2d80-dfsg1-0.6'
# WARNING: Ignoring invalid distribution -cipy (/home/ranjan/.local/lib/python3.10/site-packages)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# ==============================
# YOLO11n SEGMENTATION TRAINING
# ==============================

import os
import torch
from ultralytics import YOLO

print("=" * 60)
print("🚀 YOLO11n SEGMENTATION TRAINING START")
print("=" * 60)

# ------------------------------
# GPU CHECK
# ------------------------------
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
    print(f"✅ VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    raise RuntimeError("❌ CUDA GPU not available")

# ------------------------------
# PATHS (EDIT IF NEEDED)
# ------------------------------
dataset_path = "/home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml"
output_dir = "/home/ranjan/Documents/yolo26/earlystageapple/Experiment/YOLOv11"

os.makedirs(output_dir, exist_ok=True)

if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"❌ Dataset not found: {dataset_path}")

print(f"✅ Dataset found: {dataset_path}")

# ------------------------------
# LOAD MODEL
# ------------------------------
print("\n🔄 Loading YOLO11n-seg model...")
model = YOLO("yolo11n-seg.pt")
print("✅ Model loaded successfully")

# ------------------------------
# TRAINING CONFIG
# ------------------------------
EPOCHS = 200
IMGSZ = 640
BATCH = 8   # reduce to 4 if you hit OOM
WORKERS = 4

print("\n📊 Training Configuration:")
print(f"   Epochs      : {EPOCHS}")
print(f"   Image Size  : {IMGSZ}")
print(f"   Batch Size  : {BATCH}")
print(f"   Workers     : {WORKERS}")
print(f"   Device      : GPU (0)")

# ------------------------------
# TRAIN
# ------------------------------
try:
    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=BATCH,
        device=0,              # GPU
        workers=WORKERS,
        
        project=output_dir,
        name="yolo11n_seg_training",
        exist_ok=True,
        
        # training behavior
        pretrained=True,
        optimizer="auto",
        verbose=True,
        seed=42,
        deterministic=False,
        
        # validation + saving
        val=True,
        save=True,
        save_period=10,
        
        # performance
        amp=True,              # mixed precision (good for RTX 5000 Ada)
        cache=False,           # set True if dataset fits RAM
        
        # logging
        plots=True
    )

    print("\n" + "=" * 60)
    print("✅ TRAINING COMPLETED SUCCESSFULLY")
    print("=" * 60)
    print(f"📁 Results saved at: {output_dir}/yolo11n_seg_training")

# ------------------------------
# FALLBACK (OOM / AMP ISSUES)
# ------------------------------
except Exception as e:
    print("\n❌ Training failed:", e)
    print("\n⚠️ Switching to safe fallback config...")

    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=4,          # safer
        device=0,
        workers=0,        # avoids dataloader issues
        
        project=output_dir,
        name="yolo11n_seg_fallback",
        exist_ok=True,
        
        amp=False,        # disable mixed precision
        val=True,
        save=True
    )

    print("\n✅ Training completed with fallback settings")
# Out:
# ...
# 🚀 YOLO11n SEGMENTATION TRAINING START
# ...
# ✅ GPU: NVIDIA RTX 5000 Ada Generation
# ✅ VRAM: 33.80 GB
# ✅ Dataset found: /home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml
#
# 🔄 Loading YOLO11n-seg model...
# ✅ Model loaded successfully
#
# 📊 Training Configuration:
#    Epochs      : 200
#    Image Size  : 640
#    Batch Size  : 8
#    Workers     : 4
#    Device      : GPU (0)
# Ultralytics 8.4.43 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA RTX 5000 Ada Generation, 32237MiB)
# ...

# %%
# ==============================
# YOLO11s SEGMENTATION TRAINING
# ==============================

import os
import torch
from ultralytics import YOLO

print("=" * 60)
print("🚀 YOLO11s SEGMENTATION TRAINING START")
print("=" * 60)

# ------------------------------
# GPU CHECK
# ------------------------------
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
    print(f"✅ VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    raise RuntimeError("❌ CUDA GPU not available")

# ------------------------------
# PATHS (EDIT IF NEEDED)
# ------------------------------
dataset_path = "/home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml"
output_dir = "/home/ranjan/Documents/yolo26/earlystageapple/Experiment/YOLOv11"

os.makedirs(output_dir, exist_ok=True)

if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"❌ Dataset not found: {dataset_path}")

print(f"✅ Dataset found: {dataset_path}")

# ------------------------------
# LOAD MODEL
# ------------------------------
print("\n🔄 Loading YOLO11s-seg model...")
model = YOLO("yolo11s-seg.pt")
print("✅ Model loaded successfully")

# ------------------------------
# TRAINING CONFIG
# ------------------------------
EPOCHS = 200
IMGSZ = 640
BATCH = 8   # reduce to 4 if you hit OOM
WORKERS = 4

print("\n📊 Training Configuration:")
print(f"   Epochs      : {EPOCHS}")
print(f"   Image Size  : {IMGSZ}")
print(f"   Batch Size  : {BATCH}")
print(f"   Workers     : {WORKERS}")
print(f"   Device      : GPU (0)")

# ------------------------------
# TRAIN
# ------------------------------
try:
    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=BATCH,
        device=0,              # GPU
        workers=WORKERS,
        
        project=output_dir,
        name="yolo11s_seg_training",
        exist_ok=True,
        
        # training behavior
        pretrained=True,
        optimizer="auto",
        verbose=True,
        seed=42,
        deterministic=False,
        
        # validation + saving
        val=True,
        save=True,
        save_period=10,
        
        # performance
        amp=True,              # mixed precision (good for RTX 5000 Ada)
        cache=False,           # set True if dataset fits RAM
        
        # logging
        plots=True
    )

    print("\n" + "=" * 60)
    print("✅ TRAINING COMPLETED SUCCESSFULLY")
    print("=" * 60)
    print(f"📁 Results saved at: {output_dir}/yolo11s_seg_training")

# ------------------------------
# FALLBACK (OOM / AMP ISSUES)
# ------------------------------
except Exception as e:
    print("\n❌ Training failed:", e)
    print("\n⚠️ Switching to safe fallback config...")

    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=4,          # safer
        device=0,
        workers=0,        # avoids dataloader issues
        
        project=output_dir,
        name="yolo11s_seg_fallback",
        exist_ok=True,
        
        amp=False,        # disable mixed precision
        val=True,
        save=True
    )

    print("\n✅ Training completed with fallback settings")
# Out:
# ...
# 🚀 YOLO11s SEGMENTATION TRAINING START
# ...
# ✅ GPU: NVIDIA RTX 5000 Ada Generation
# ✅ VRAM: 33.80 GB
# ✅ Dataset found: /home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml
#
# 🔄 Loading YOLO11s-seg model...
# ...
# ✅ Model loaded successfully
#
# 📊 Training Configuration:
#    Epochs      : 200
#    Image Size  : 640
#    Batch Size  : 8
#    Workers     : 4
#    Device      : GPU (0)
# Ultralytics 8.4.43 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA RTX 5000 Ada Generation, 32237MiB)
# ...

# %%
# ==============================
# YOLO11m SEGMENTATION TRAINING
# ==============================

import os
import torch
from ultralytics import YOLO

print("=" * 60)
print("🚀 YOLO11m SEGMENTATION TRAINING START")
print("=" * 60)

# ------------------------------
# GPU CHECK
# ------------------------------
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
    print(f"✅ VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    raise RuntimeError("❌ CUDA GPU not available")

# ------------------------------
# PATHS (EDIT IF NEEDED)
# ------------------------------
dataset_path = "/home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml"
output_dir = "/home/ranjan/Documents/yolo26/earlystageapple/Experiment/YOLOv11"

os.makedirs(output_dir, exist_ok=True)

if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"❌ Dataset not found: {dataset_path}")

print(f"✅ Dataset found: {dataset_path}")

# ------------------------------
# LOAD MODEL
# ------------------------------
print("\n🔄 Loading YOLO11m-seg model...")
model = YOLO("yolo11m-seg.pt")
print("✅ Model loaded successfully")

# ------------------------------
# TRAINING CONFIG
# ------------------------------
EPOCHS = 200
IMGSZ = 640
BATCH = 8   # reduce to 4 if you hit OOM
WORKERS = 4

print("\n📊 Training Configuration:")
print(f"   Epochs      : {EPOCHS}")
print(f"   Image Size  : {IMGSZ}")
print(f"   Batch Size  : {BATCH}")
print(f"   Workers     : {WORKERS}")
print(f"   Device      : GPU (0)")

# ------------------------------
# TRAIN
# ------------------------------
try:
    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=BATCH,
        device=0,              # GPU
        workers=WORKERS,
        
        project=output_dir,
        name="yolo11m_seg_training",
        exist_ok=True,
        
        # training behavior
        pretrained=True,
        optimizer="auto",
        verbose=True,
        seed=42,
        deterministic=False,
        
        # validation + saving
        val=True,
        save=True,
        save_period=10,
        
        # performance
        amp=True,              # mixed precision (good for RTX 5000 Ada)
        cache=False,           # set True if dataset fits RAM
        
        # logging
        plots=True
    )

    print("\n" + "=" * 60)
    print("✅ TRAINING COMPLETED SUCCESSFULLY")
    print("=" * 60)
    print(f"📁 Results saved at: {output_dir}/yolo11m_seg_training")

# ------------------------------
# FALLBACK (OOM / AMP ISSUES)
# ------------------------------
except Exception as e:
    print("\n❌ Training failed:", e)
    print("\n⚠️ Switching to safe fallback config...")

    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=4,          # safer
        device=0,
        workers=0,        # avoids dataloader issues
        
        project=output_dir,
        name="yolo11m_seg_fallback",
        exist_ok=True,
        
        amp=False,        # disable mixed precision
        val=True,
        save=True
    )

    print("\n✅ Training completed with fallback settings")
# Out:
# ...
# 🚀 YOLO11m SEGMENTATION TRAINING START
# ...
# ✅ GPU: NVIDIA RTX 5000 Ada Generation
# ✅ VRAM: 33.80 GB
# ✅ Dataset found: /home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml
#
# 🔄 Loading YOLO11m-seg model...
# ...
# ✅ Model loaded successfully
#
# 📊 Training Configuration:
#    Epochs      : 200
#    Image Size  : 640
#    Batch Size  : 8
#    Workers     : 4
#    Device      : GPU (0)
# Ultralytics 8.4.43 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA RTX 5000 Ada Generation, 32237MiB)
# ...

# %%
# ==============================
# YOLO11l SEGMENTATION TRAINING
# ==============================

import os
import torch
from ultralytics import YOLO

print("=" * 60)
print("🚀 YOLO11l SEGMENTATION TRAINING START")
print("=" * 60)

# ------------------------------
# GPU CHECK
# ------------------------------
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
    print(f"✅ VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    raise RuntimeError("❌ CUDA GPU not available")

# ------------------------------
# PATHS (EDIT IF NEEDED)
# ------------------------------
dataset_path = "/home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml"
output_dir = "/home/ranjan/Documents/yolo26/earlystageapple/Experiment/YOLOv11"

os.makedirs(output_dir, exist_ok=True)

if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"❌ Dataset not found: {dataset_path}")

print(f"✅ Dataset found: {dataset_path}")

# ------------------------------
# LOAD MODEL
# ------------------------------
print("\n🔄 Loading YOLO11l-seg model...")
model = YOLO("yolo11l-seg.pt")
print("✅ Model loaded successfully")

# ------------------------------
# TRAINING CONFIG
# ------------------------------
EPOCHS = 200
IMGSZ = 640
BATCH = 8   # reduce to 4 if you hit OOM
WORKERS = 4

print("\n📊 Training Configuration:")
print(f"   Epochs      : {EPOCHS}")
print(f"   Image Size  : {IMGSZ}")
print(f"   Batch Size  : {BATCH}")
print(f"   Workers     : {WORKERS}")
print(f"   Device      : GPU (0)")

# ------------------------------
# TRAIN
# ------------------------------
try:
    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=BATCH,
        device=0,              # GPU
        workers=WORKERS,
        
        project=output_dir,
        name="yolo11l_seg_training",
        exist_ok=True,
        
        # training behavior
        pretrained=True,
        optimizer="auto",
        verbose=True,
        seed=42,
        deterministic=False,
        
        # validation + saving
        val=True,
        save=True,
        save_period=10,
        
        # performance
        amp=True,              # mixed precision (good for RTX 5000 Ada)
        cache=False,           # set True if dataset fits RAM
        
        # logging
        plots=True
    )

    print("\n" + "=" * 60)
    print("✅ TRAINING COMPLETED SUCCESSFULLY")
    print("=" * 60)
    print(f"📁 Results saved at: {output_dir}/yolo11l_seg_training")

# ------------------------------
# FALLBACK (OOM / AMP ISSUES)
# ------------------------------
except Exception as e:
    print("\n❌ Training failed:", e)
    print("\n⚠️ Switching to safe fallback config...")

    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=4,          # safer
        device=0,
        workers=0,        # avoids dataloader issues
        
        project=output_dir,
        name="yolo11l_seg_fallback",
        exist_ok=True,
        
        amp=False,        # disable mixed precision
        val=True,
        save=True
    )

    print("\n✅ Training completed with fallback settings")
# Out:
# ...
# 🚀 YOLO11l SEGMENTATION TRAINING START
# ...
# ✅ GPU: NVIDIA RTX 5000 Ada Generation
# ✅ VRAM: 33.80 GB
# ✅ Dataset found: /home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml
#
# 🔄 Loading YOLO11l-seg model...
# ...
# ✅ Model loaded successfully
#
# 📊 Training Configuration:
#    Epochs      : 200
#    Image Size  : 640
#    Batch Size  : 8
#    Workers     : 4
#    Device      : GPU (0)
# Ultralytics 8.4.43 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA RTX 5000 Ada Generation, 32237MiB)
# ...

# %%
# ==============================
# YOLO11x SEGMENTATION TRAINING
# ==============================

import os
import torch
from ultralytics import YOLO

print("=" * 60)
print("🚀 YOLO11x SEGMENTATION TRAINING START")
print("=" * 60)

# ------------------------------
# GPU CHECK
# ------------------------------
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
    print(f"✅ VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    raise RuntimeError("❌ CUDA GPU not available")

# ------------------------------
# PATHS (EDIT IF NEEDED)
# ------------------------------
dataset_path = "/home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml"
output_dir = "/home/ranjan/Documents/yolo26/earlystageapple/Experiment/YOLOv11"

os.makedirs(output_dir, exist_ok=True)

if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"❌ Dataset not found: {dataset_path}")

print(f"✅ Dataset found: {dataset_path}")

# ------------------------------
# LOAD MODEL
# ------------------------------
print("\n🔄 Loading YOLO11x-seg model...")
model = YOLO("yolo11x-seg.pt")
print("✅ Model loaded successfully")

# ------------------------------
# TRAINING CONFIG
# ------------------------------
EPOCHS = 200
IMGSZ = 640
BATCH = 8   # reduce to 4 if you hit OOM
WORKERS = 4

print("\n📊 Training Configuration:")
print(f"   Epochs      : {EPOCHS}")
print(f"   Image Size  : {IMGSZ}")
print(f"   Batch Size  : {BATCH}")
print(f"   Workers     : {WORKERS}")
print(f"   Device      : GPU (0)")

# ------------------------------
# TRAIN
# ------------------------------
try:
    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=BATCH,
        device=0,              # GPU
        workers=WORKERS,
        
        project=output_dir,
        name="yolo11x_seg_training",
        exist_ok=True,
        
        # training behavior
        pretrained=True,
        optimizer="auto",
        verbose=True,
        seed=42,
        deterministic=False,
        
        # validation + saving
        val=True,
        save=True,
        save_period=10,
        
        # performance
        amp=True,              # mixed precision (good for RTX 5000 Ada)
        cache=False,           # set True if dataset fits RAM
        
        # logging
        plots=True
    )

    print("\n" + "=" * 60)
    print("✅ TRAINING COMPLETED SUCCESSFULLY")
    print("=" * 60)
    print(f"📁 Results saved at: {output_dir}/yolo11x_seg_training")

# ------------------------------
# FALLBACK (OOM / AMP ISSUES)
# ------------------------------
except Exception as e:
    print("\n❌ Training failed:", e)
    print("\n⚠️ Switching to safe fallback config...")

    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=4,          # safer
        device=0,
        workers=0,        # avoids dataloader issues
        
        project=output_dir,
        name="yolo11x_seg_fallback",
        exist_ok=True,
        
        amp=False,        # disable mixed precision
        val=True,
        save=True
    )

    print("\n✅ Training completed with fallback settings")
# Out:
# ...
# 🚀 YOLO11x SEGMENTATION TRAINING START
# ...
# ✅ GPU: NVIDIA RTX 5000 Ada Generation
# ✅ VRAM: 33.80 GB
# ✅ Dataset found: /home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml
#
# 🔄 Loading YOLO11x-seg model...
# ✅ Model loaded successfully
#
# 📊 Training Configuration:
#    Epochs      : 200
#    Image Size  : 640
#    Batch Size  : 8
#    Workers     : 4
#    Device      : GPU (0)
# Ultralytics 8.4.43 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA RTX 5000 Ada Generation, 32237MiB)
# ...

# %%
# ==============================
# YOLO11n SAHI-READY TRAINING
# ==============================

import os
import torch
from ultralytics import YOLO

print("=" * 60)
print("YOLO11n SAHI-READY TRAINING (SMALL OBJECT FOCUS)")
print("=" * 60)

# ------------------------------
# GPU SETUP
# ------------------------------
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    device = 0
    print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
    print(f"✅ VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    device = "cpu"
    print("⚠️ No GPU found, using CPU")

# ------------------------------
# PATHS
# ------------------------------
dataset_path = "/home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml"
output_dir = "/home/ranjan/Documents/yolo26/earlystageapple/Experiment/YOLOv11/YOLO11sahi"

os.makedirs(output_dir, exist_ok=True)

if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"❌ Dataset not found: {dataset_path}")

print(f"✅ Dataset found: {dataset_path}")

# ------------------------------
# LOAD MODEL
# ------------------------------
print("\n🔄 Loading YOLO11n-seg model...")
model = YOLO("yolo11n-seg.pt")
print("✅ Model loaded")

# ------------------------------
# TRAINING CONFIG (SAHI-OPTIMIZED)
# ------------------------------
EPOCHS = 200
IMGSZ = 960          # larger = better for small objects
BATCH = 8            # reduce if OOM
WORKERS = 2

print("\n📊 Training Configuration:")
print(f"   Epochs      : {EPOCHS}")
print(f"   Image Size  : {IMGSZ}")
print(f"   Batch Size  : {BATCH}")
print(f"   Workers     : {WORKERS}")
print(f"   Device      : {device}")

# ------------------------------
# TRAIN
# ------------------------------
print("\n🚀 Starting training...\n")

try:
    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=BATCH,
        device=device,
        workers=WORKERS,

        # output
        project=output_dir,
        name="yolo11n_sahi",
        exist_ok=True,

        # training behavior
        pretrained=True,
        optimizer="auto",
        verbose=True,

        # small-object friendly tweaks
        scale=0.5,        # less aggressive scaling
        mosaic=1.0,
        close_mosaic=10,  # stabilize later epochs

        # validation
        val=True,
        save=True,
        save_period=10,

        # performance
        amp=True if device != "cpu" else False,
        cache=False,

        # logging
        plots=True
    )

    print("\n" + "=" * 60)
    print("✅ TRAINING COMPLETED SUCCESSFULLY")
    print("=" * 60)
    print(f"📁 Saved at: {output_dir}/yolo11n_sahi")

# ------------------------------
# FALLBACK (SAFE MODE)
# ------------------------------
except Exception as e:
    print("\n❌ Training failed:", e)
    print("\n⚠️ Switching to safe fallback config...")

    results = model.train(
        data=dataset_path,
        epochs=100,
        imgsz=IMGSZ,
        batch=4,
        device=device,
        workers=0,

        project=output_dir,
        name="yolo11n_sahi_fallback",
        exist_ok=True,

        amp=False,
        val=True,
        save=True
    )

    print("\n✅ Training completed with fallback settings")

print("\n🎯 YOLO11n SAHI-ready model training complete!")
# Out:
# ...
# YOLO11n SAHI-READY TRAINING (SMALL OBJECT FOCUS)
# ...
# ✅ GPU: NVIDIA RTX 5000 Ada Generation
# ✅ VRAM: 33.80 GB
# ✅ Dataset found: /home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml
#
# 🔄 Loading YOLO11n-seg model...
# ✅ Model loaded
#
# 📊 Training Configuration:
#    Epochs      : 200
#    Image Size  : 960
#    Batch Size  : 8
#    Workers     : 2
#    Device      : 0
#
# 🚀 Starting training...
#
# Ultralytics 8.4.43 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA RTX 5000 Ada Generation, 32237MiB)
# ...

# %%
# ==============================
# YOLO11s SAHI-READY TRAINING
# ==============================

import os
import torch
from ultralytics import YOLO

print("=" * 60)
print("YOLO11s SAHI-READY TRAINING (SMALL OBJECT FOCUS)")
print("=" * 60)

# ------------------------------
# GPU SETUP
# ------------------------------
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    device = 0
    print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
    print(f"✅ VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    device = "cpu"
    print("⚠️ No GPU found, using CPU")

# ------------------------------
# PATHS
# ------------------------------
dataset_path = "/home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml"
output_dir = "/home/ranjan/Documents/yolo26/earlystageapple/Experiment/YOLOv11/YOLO11sahi"

os.makedirs(output_dir, exist_ok=True)

if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"❌ Dataset not found: {dataset_path}")

print(f"✅ Dataset found: {dataset_path}")

# ------------------------------
# LOAD MODEL
# ------------------------------
print("\n🔄 Loading YOLO11s-seg model...")
model = YOLO("yolo11s-seg.pt")
print("✅ Model loaded")

# ------------------------------
# TRAINING CONFIG (SAHI-OPTIMIZED)
# ------------------------------
EPOCHS = 200
IMGSZ = 960          # larger = better for small objects
BATCH = 8            # reduce if OOM
WORKERS = 2

print("\n📊 Training Configuration:")
print(f"   Epochs      : {EPOCHS}")
print(f"   Image Size  : {IMGSZ}")
print(f"   Batch Size  : {BATCH}")
print(f"   Workers     : {WORKERS}")
print(f"   Device      : {device}")

# ------------------------------
# TRAIN
# ------------------------------
print("\n🚀 Starting training...\n")

try:
    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=BATCH,
        device=device,
        workers=WORKERS,

        # output
        project=output_dir,
        name="yolo11s_sahi",
        exist_ok=True,

        # training behavior
        pretrained=True,
        optimizer="auto",
        verbose=True,

        # small-object friendly tweaks
        scale=0.5,        # less aggressive scaling
        mosaic=1.0,
        close_mosaic=10,  # stabilize later epochs

        # validation
        val=True,
        save=True,
        save_period=10,

        # performance
        amp=True if device != "cpu" else False,
        cache=False,

        # logging
        plots=True
    )

    print("\n" + "=" * 60)
    print("✅ TRAINING COMPLETED SUCCESSFULLY")
    print("=" * 60)
    print(f"📁 Saved at: {output_dir}/yolo11s_sahi")

# ------------------------------
# FALLBACK (SAFE MODE)
# ------------------------------
except Exception as e:
    print("\n❌ Training failed:", e)
    print("\n⚠️ Switching to safe fallback config...")

    results = model.train(
        data=dataset_path,
        epochs=100,
        imgsz=IMGSZ,
        batch=4,
        device=device,
        workers=0,

        project=output_dir,
        name="yolo11s_sahi_fallback",
        exist_ok=True,

        amp=False,
        val=True,
        save=True
    )

    print("\s✅ Training completed with fallback settings")

print("\n🎯 YOLO11s SAHI-ready model training complete!")
# Out:
# ...
# YOLO11s SAHI-READY TRAINING (SMALL OBJECT FOCUS)
# ...
# ✅ GPU: NVIDIA RTX 5000 Ada Generation
# ✅ VRAM: 33.80 GB
# ✅ Dataset found: /home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml
#
# 🔄 Loading YOLO11s-seg model...
# ✅ Model loaded
#
# 📊 Training Configuration:
#    Epochs      : 200
#    Image Size  : 960
#    Batch Size  : 8
#    Workers     : 2
#    Device      : 0
#
# 🚀 Starting training...
#
# Ultralytics 8.4.43 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA RTX 5000 Ada Generation, 32237MiB)
# ...

# %%
# ==============================
# YOLO11m SAHI-READY TRAINING
# ==============================

import os
import torch
from ultralytics import YOLO

print("=" * 60)
print("YOLO11m SAHI-READY TRAINING (SMALL OBJECT FOCUS)")
print("=" * 60)

# ------------------------------
# GPU SETUP
# ------------------------------
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    device = 0
    print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
    print(f"✅ VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    device = "cpu"
    print("⚠️ No GPU found, using CPU")

# ------------------------------
# PATHS
# ------------------------------
dataset_path = "/home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml"
output_dir = "/home/ranjan/Documents/yolo26/earlystageapple/Experiment/YOLOv11/YOLO11sahi"

os.makedirs(output_dir, exist_ok=True)

if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"❌ Dataset not found: {dataset_path}")

print(f"✅ Dataset found: {dataset_path}")

# ------------------------------
# LOAD MODEL
# ------------------------------
print("\n🔄 Loading YOLO11m-seg model...")
model = YOLO("yolo11m-seg.pt")
print("✅ Model loaded")

# ------------------------------
# TRAINING CONFIG (SAHI-OPTIMIZED)
# ------------------------------
EPOCHS = 200
IMGSZ = 960          # larger = better for small objects
BATCH = 8            # reduce if OOM
WORKERS = 2

print("\n📊 Training Configuration:")
print(f"   Epochs      : {EPOCHS}")
print(f"   Image Size  : {IMGSZ}")
print(f"   Batch Size  : {BATCH}")
print(f"   Workers     : {WORKERS}")
print(f"   Device      : {device}")

# ------------------------------
# TRAIN
# ------------------------------
print("\n🚀 Starting training...\n")

try:
    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=BATCH,
        device=device,
        workers=WORKERS,

        # output
        project=output_dir,
        name="yolo11m_sahi",
        exist_ok=True,

        # training behavior
        pretrained=True,
        optimizer="auto",
        verbose=True,

        # small-object friendly tweaks
        scale=0.5,        # less aggressive scaling
        mosaic=1.0,
        close_mosaic=10,  # stabilize later epochs

        # validation
        val=True,
        save=True,
        save_period=10,

        # performance
        amp=True if device != "cpu" else False,
        cache=False,

        # logging
        plots=True
    )

    print("\n" + "=" * 60)
    print("✅ TRAINING COMPLETED SUCCESSFULLY")
    print("=" * 60)
    print(f"📁 Saved at: {output_dir}/yolo11m_sahi")

# ------------------------------
# FALLBACK (SAFE MODE)
# ------------------------------
except Exception as e:
    print("\n❌ Training failed:", e)
    print("\n⚠️ Switching to safe fallback config...")

    results = model.train(
        data=dataset_path,
        epochs=100,
        imgsz=IMGSZ,
        batch=4,
        device=device,
        workers=0,

        project=output_dir,
        name="yolo11m_sahi_fallback",
        exist_ok=True,

        amp=False,
        val=True,
        save=True
    )

    print("\m✅ Training completed with fallback settings")

print("\n🎯 YOLO11m SAHI-ready model training complete!")
# Out:
# ...
# YOLO11m SAHI-READY TRAINING (SMALL OBJECT FOCUS)
# ...
# ✅ GPU: NVIDIA RTX 5000 Ada Generation
# ✅ VRAM: 33.80 GB
# ✅ Dataset found: /home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml
#
# 🔄 Loading YOLO11m-seg model...
# ✅ Model loaded
#
# 📊 Training Configuration:
#    Epochs      : 200
#    Image Size  : 960
#    Batch Size  : 8
#    Workers     : 2
#    Device      : 0
#
# 🚀 Starting training...
#
# New https://pypi.org/project/ultralytics/8.4.44 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.43 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA RTX 5000 Ada Generation, 32237MiB)
# ...

# %%
# ==============================
# YOLO11l SAHI-READY TRAINING
# ==============================

import os
import torch
from ultralytics import YOLO

print("=" * 60)
print("YOLO11l SAHI-READY TRAINING (SMALL OBJECT FOCUS)")
print("=" * 60)

# ------------------------------
# GPU SETUP
# ------------------------------
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    device = 0
    print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
    print(f"✅ VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    device = "cpu"
    print("⚠️ No GPU found, using CPU")

# ------------------------------
# PATHS
# ------------------------------
dataset_path = "/home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml"
output_dir = "/home/ranjan/Documents/yolo26/earlystageapple/Experiment/YOLOv11/YOLO11sahi"

os.makedirs(output_dir, exist_ok=True)

if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"❌ Dataset not found: {dataset_path}")

print(f"✅ Dataset found: {dataset_path}")

# ------------------------------
# LOAD MODEL
# ------------------------------
print("\n🔄 Loading YOLO11l-seg model...")
model = YOLO("yolo11l-seg.pt")
print("✅ Model loaded")

# ------------------------------
# TRAINING CONFIG (SAHI-OPTIMIZED)
# ------------------------------
EPOCHS = 200
IMGSZ = 960          # larger = better for small objects
BATCH = 8            # reduce if OOM
WORKERS = 2

print("\n📊 Training Configuration:")
print(f"   Epochs      : {EPOCHS}")
print(f"   Image Size  : {IMGSZ}")
print(f"   Batch Size  : {BATCH}")
print(f"   Workers     : {WORKERS}")
print(f"   Device      : {device}")

# ------------------------------
# TRAIN
# ------------------------------
print("\n🚀 Starting training...\n")

try:
    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=BATCH,
        device=device,
        workers=WORKERS,

        # output
        project=output_dir,
        name="yolo11l_sahi",
        exist_ok=True,

        # training behavior
        pretrained=True,
        optimizer="auto",
        verbose=True,

        # small-object friendly tweaks
        scale=0.5,        # less aggressive scaling
        mosaic=1.0,
        close_mosaic=10,  # stabilize later epochs

        # validation
        val=True,
        save=True,
        save_period=10,

        # performance
        amp=True if device != "cpu" else False,
        cache=False,

        # logging
        plots=True
    )

    print("\n" + "=" * 60)
    print("✅ TRAINING COMPLETED SUCCESSFULLY")
    print("=" * 60)
    print(f"📁 Saved at: {output_dir}/yolo11l_sahi")

# ------------------------------
# FALLBACK (SAFE MODE)
# ------------------------------
except Exception as e:
    print("\n❌ Training failed:", e)
    print("\n⚠️ Switching to safe fallback config...")

    results = model.train(
        data=dataset_path,
        epochs=100,
        imgsz=IMGSZ,
        batch=4,
        device=device,
        workers=0,

        project=output_dir,
        name="yolo11l_sahi_fallback",
        exist_ok=True,

        amp=False,
        val=True,
        save=True
    )

    print("\l✅ Training completed with fallback settings")

print("\n🎯 YOLO11l SAHI-ready model training complete!")
# Out:
# ...
# YOLO11l SAHI-READY TRAINING (SMALL OBJECT FOCUS)
# ...
# ✅ GPU: NVIDIA RTX 5000 Ada Generation
# ✅ VRAM: 33.80 GB
# ✅ Dataset found: /home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml
#
# 🔄 Loading YOLO11l-seg model...
# ✅ Model loaded
#
# 📊 Training Configuration:
#    Epochs      : 200
#    Image Size  : 960
#    Batch Size  : 8
#    Workers     : 2
#    Device      : 0
#
# 🚀 Starting training...
#
# New https://pypi.org/project/ultralytics/8.4.45 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.43 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA RTX 5000 Ada Generation, 32237MiB)
# ...

# %%
# ==============================
# YOLO11x SAHI-READY TRAINING
# ==============================

import os
import torch
from ultralytics import YOLO

print("=" * 60)
print("YOLO11x SAHI-READY TRAINING (SMALL OBJECT FOCUS)")
print("=" * 60)

# ------------------------------
# GPU SETUP
# ------------------------------
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    device = 0
    print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
    print(f"✅ VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    device = "cpu"
    print("⚠️ No GPU found, using CPU")

# ------------------------------
# PATHS
# ------------------------------
dataset_path = "/home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml"
output_dir = "/home/ranjan/Documents/yolo26/earlystageapple/Experiment/YOLOv11/YOLO11sahi"

os.makedirs(output_dir, exist_ok=True)

if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"❌ Dataset not found: {dataset_path}")

print(f"✅ Dataset found: {dataset_path}")

# ------------------------------
# LOAD MODEL
# ------------------------------
print("\n🔄 Loading YOLO11x-seg model...")
model = YOLO("yolo11x-seg.pt")
print("✅ Model loaded")

# ------------------------------
# TRAINING CONFIG (SAHI-OPTIMIZED)
# ------------------------------
EPOCHS = 200
IMGSZ = 960          # larger = better for small objects
BATCH = 8            # reduce if OOM
WORKERS = 2

print("\n📊 Training Configuration:")
print(f"   Epochs      : {EPOCHS}")
print(f"   Image Size  : {IMGSZ}")
print(f"   Batch Size  : {BATCH}")
print(f"   Workers     : {WORKERS}")
print(f"   Device      : {device}")

# ------------------------------
# TRAIN
# ------------------------------
print("\n🚀 Starting training...\n")

try:
    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=BATCH,
        device=device,
        workers=WORKERS,

        # output
        project=output_dir,
        name="yolo11x_sahi",
        exist_ok=True,

        # training behavior
        pretrained=True,
        optimizer="auto",
        verbose=True,

        # small-object friendly tweaks
        scale=0.5,        # less aggressive scaling
        mosaic=1.0,
        close_mosaic=10,  # stabilize later epochs

        # validation
        val=True,
        save=True,
        save_period=10,

        # performance
        amp=True if device != "cpu" else False,
        cache=False,

        # logging
        plots=True
    )

    print("\n" + "=" * 60)
    print("✅ TRAINING COMPLETED SUCCESSFULLY")
    print("=" * 60)
    print(f"📁 Saved at: {output_dir}/yolo11x_sahi")

# ------------------------------
# FALLBACK (SAFE MODE)
# ------------------------------
except Exception as e:
    print("\n❌ Training failed:", e)
    print("\n⚠️ Switching to safe fallback config...")

    results = model.train(
        data=dataset_path,
        epochs=100,
        imgsz=IMGSZ,
        batch=4,
        device=device,
        workers=0,

        project=output_dir,
        name="yolo11x_sahi_fallback",
        exist_ok=True,

        amp=False,
        val=True,
        save=True
    )

    print("\l✅ Training completed with fallback settings")

print("\n🎯 YOLO11x SAHI-ready model training complete!")
# Out:
# ...
# YOLO11x SAHI-READY TRAINING (SMALL OBJECT FOCUS)
# ...
# ✅ GPU: NVIDIA RTX 5000 Ada Generation
# ✅ VRAM: 33.80 GB
# ✅ Dataset found: /home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml
#
# 🔄 Loading YOLO11x-seg model...
# ✅ Model loaded
#
# 📊 Training Configuration:
#    Epochs      : 200
#    Image Size  : 960
#    Batch Size  : 8
#    Workers     : 2
#    Device      : 0
#
# 🚀 Starting training...
#
# New https://pypi.org/project/ultralytics/8.4.45 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.43 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA RTX 5000 Ada Generation, 32237MiB)
# ...

# %%
# ==============================
# YOLOv8n SEGMENTATION TRAINING
# ==============================

import os
import torch
from ultralytics import YOLO

print("=" * 60)
print("🚀 YOLOv8n SEGMENTATION TRAINING START")
print("=" * 60)

# ------------------------------
# GPU CHECK
# ------------------------------
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
    print(f"✅ VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    raise RuntimeError("❌ CUDA GPU not available")

# ------------------------------
# PATHS (EDIT IF NEEDED)
# ------------------------------
dataset_path = "/home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml"
output_dir = "/home/ranjan/Documents/yolo26/earlystageapple/Experiment/YOLOv8"

os.makedirs(output_dir, exist_ok=True)

if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"❌ Dataset not found: {dataset_path}")

print(f"✅ Dataset found: {dataset_path}")

# ------------------------------
# LOAD MODEL
# ------------------------------
print("\n🔄 Loading YOLOv8n-seg model...")
model = YOLO("yolov8n-seg.pt")
print("✅ Model loaded successfully")

# ------------------------------
# TRAINING CONFIG
# ------------------------------
EPOCHS = 200
IMGSZ = 640
BATCH = 8   # reduce to 4 if you hit OOM
WORKERS = 4

print("\n📊 Training Configuration:")
print(f"   Epochs      : {EPOCHS}")
print(f"   Image Size  : {IMGSZ}")
print(f"   Batch Size  : {BATCH}")
print(f"   Workers     : {WORKERS}")
print(f"   Device      : GPU (0)")

# ------------------------------
# TRAIN
# ------------------------------
try:
    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=BATCH,
        device=0,              # GPU
        workers=WORKERS,
        
        project=output_dir,
        name="yolov8n_seg_training",
        exist_ok=True,
        
        # training behavior
        pretrained=True,
        optimizer="auto",
        verbose=True,
        seed=42,
        deterministic=False,
        
        # validation + saving
        val=True,
        save=True,
        save_period=10,
        
        # performance
        amp=True,              # mixed precision
        cache=False,           # set True if dataset fits RAM
        
        # logging
        plots=True
    )

    print("\n" + "=" * 60)
    print("✅ TRAINING COMPLETED SUCCESSFULLY")
    print("=" * 60)
    print(f"📁 Results saved at: {output_dir}/yolov8n_seg_training")

# ------------------------------
# FALLBACK (OOM / AMP ISSUES)
# ------------------------------
except Exception as e:
    print("\n❌ Training failed:", e)
    print("\n⚠️ Switching to safe fallback config...")

    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=4,          # safer
        device=0,
        workers=0,        # avoids dataloader issues
        
        project=output_dir,
        name="yolov8n_seg_fallback",
        exist_ok=True,
        
        amp=False,        # disable mixed precision
        val=True,
        save=True
    )

    print("\n✅ Training completed with fallback settings")
# Out:
# ...
# 🚀 YOLOv8n SEGMENTATION TRAINING START
# ...
# ✅ GPU: NVIDIA RTX 5000 Ada Generation
# ✅ VRAM: 33.80 GB
# ✅ Dataset found: /home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml
#
# 🔄 Loading YOLOv8n-seg model...
# ✅ Model loaded successfully
#
# 📊 Training Configuration:
#    Epochs      : 200
#    Image Size  : 640
#    Batch Size  : 8
#    Workers     : 4
#    Device      : GPU (0)
# New https://pypi.org/project/ultralytics/8.4.45 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.43 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA RTX 5000 Ada Generation, 32237MiB)
# ...

# %%
# ==============================
# YOLOv8s SEGMENTATION TRAINING
# ==============================

import os
import torch
from ultralytics import YOLO

print("=" * 60)
print("🚀 YOLOv8s SEGMENTATION TRAINING START")
print("=" * 60)

# ------------------------------
# GPU CHECK
# ------------------------------
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
    print(f"✅ VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    raise RuntimeError("❌ CUDA GPU not available")

# ------------------------------
# PATHS (EDIT IF NEEDED)
# ------------------------------
dataset_path = "/home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml"
output_dir = "/home/ranjan/Documents/yolo26/earlystageapple/Experiment/YOLOv8"

os.makedirs(output_dir, exist_ok=True)

if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"❌ Dataset not found: {dataset_path}")

print(f"✅ Dataset found: {dataset_path}")

# ------------------------------
# LOAD MODEL
# ------------------------------
print("\n🔄 Loading YOLOv8s-seg model...")
model = YOLO("yolov8s-seg.pt")
print("✅ Model loaded successfully")

# ------------------------------
# TRAINING CONFIG
# ------------------------------
EPOCHS = 200
IMGSZ = 640
BATCH = 8   # reduce to 4 if you hit OOM
WORKERS = 4

print("\n📊 Training Configuration:")
print(f"   Epochs      : {EPOCHS}")
print(f"   Image Size  : {IMGSZ}")
print(f"   Batch Size  : {BATCH}")
print(f"   Workers     : {WORKERS}")
print(f"   Device      : GPU (0)")

# ------------------------------
# TRAIN
# ------------------------------
try:
    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=BATCH,
        device=0,              # GPU
        workers=WORKERS,
        
        project=output_dir,
        name="yolov8s_seg_training",
        exist_ok=True,
        
        # training behavior
        pretrained=True,
        optimizer="auto",
        verbose=True,
        seed=42,
        deterministic=False,
        
        # validation + saving
        val=True,
        save=True,
        save_period=10,
        
        # performance
        amp=True,              # mixed precision
        cache=False,           # set True if dataset fits RAM
        
        # logging
        plots=True
    )

    print("\n" + "=" * 60)
    print("✅ TRAINING COMPLETED SUCCESSFULLY")
    print("=" * 60)
    print(f"📁 Results saved at: {output_dir}/yolov8s_seg_training")

# ------------------------------
# FALLBACK (OOM / AMP ISSUES)
# ------------------------------
except Exception as e:
    print("\n❌ Training failed:", e)
    print("\n⚠️ Switching to safe fallback config...")

    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=4,          # safer
        device=0,
        workers=0,        # avoids dataloader issues
        
        project=output_dir,
        name="yolov8s_seg_fallback",
        exist_ok=True,
        
        amp=False,        # disable mixed precision
        val=True,
        save=True
    )

    print("\n✅ Training completed with fallback settings")
# Out:
# ...
# 🚀 YOLOv8s SEGMENTATION TRAINING START
# ...
# ✅ GPU: NVIDIA RTX 5000 Ada Generation
# ✅ VRAM: 33.80 GB
# ✅ Dataset found: /home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml
#
# 🔄 Loading YOLOv8s-seg model...
# ...
# ✅ Model loaded successfully
#
# 📊 Training Configuration:
#    Epochs      : 200
#    Image Size  : 640
#    Batch Size  : 8
#    Workers     : 4
#    Device      : GPU (0)
# New https://pypi.org/project/ultralytics/8.4.45 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.43 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA RTX 5000 Ada Generation, 32237MiB)
# ...

# %%
# ==============================
# YOLOv8m SEGMENTATION TRAINING
# ==============================

import os
import torch
from ultralytics import YOLO

print("=" * 60)
print("🚀 YOLOv8m SEGMENTATION TRAINING START")
print("=" * 60)

# ------------------------------
# GPU CHECK
# ------------------------------
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
    print(f"✅ VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    raise RuntimeError("❌ CUDA GPU not available")

# ------------------------------
# PATHS (EDIT IF NEEDED)
# ------------------------------
dataset_path = "/home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml"
output_dir = "/home/ranjan/Documents/yolo26/earlystageapple/Experiment/YOLOv8"

os.makedirs(output_dir, exist_ok=True)

if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"❌ Dataset not found: {dataset_path}")

print(f"✅ Dataset found: {dataset_path}")

# ------------------------------
# LOAD MODEL
# ------------------------------
print("\n🔄 Loading YOLOv8m-seg model...")
model = YOLO("yolov8m-seg.pt")
print("✅ Model loaded successfully")

# ------------------------------
# TRAINING CONFIG
# ------------------------------
EPOCHS = 200
IMGSZ = 640
BATCH = 8   # reduce to 4 if you hit OOM
WORKERS = 4

print("\n📊 Training Configuration:")
print(f"   Epochs      : {EPOCHS}")
print(f"   Image Size  : {IMGSZ}")
print(f"   Batch Size  : {BATCH}")
print(f"   Workers     : {WORKERS}")
print(f"   Device      : GPU (0)")

# ------------------------------
# TRAIN
# ------------------------------
try:
    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=BATCH,
        device=0,              # GPU
        workers=WORKERS,
        
        project=output_dir,
        name="yolov8m_seg_training",
        exist_ok=True,
        
        # training behavior
        pretrained=True,
        optimizer="auto",
        verbose=True,
        seed=42,
        deterministic=False,
        
        # validation + saving
        val=True,
        save=True,
        save_period=10,
        
        # performance
        amp=True,              # mixed precision
        cache=False,           # set True if dataset fits RAM
        
        # logging
        plots=True
    )

    print("\n" + "=" * 60)
    print("✅ TRAINING COMPLETED SUCCESSFULLY")
    print("=" * 60)
    print(f"📁 Results saved at: {output_dir}/yolov8m_seg_training")

# ------------------------------
# FALLBACK (OOM / AMP ISSUES)
# ------------------------------
except Exception as e:
    print("\n❌ Training failed:", e)
    print("\n⚠️ Switching to safe fallback config...")

    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=4,          # safer
        device=0,
        workers=0,        # avoids dataloader issues
        
        project=output_dir,
        name="yolov8m_seg_fallback",
        exist_ok=True,
        
        amp=False,        # disable mixed precision
        val=True,
        save=True
    )

    print("\n✅ Training completed with fallback settings")
# Out:
# ...
# 🚀 YOLOv8m SEGMENTATION TRAINING START
# ...
# ✅ GPU: NVIDIA RTX 5000 Ada Generation
# ✅ VRAM: 33.80 GB
# ✅ Dataset found: /home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml
#
# 🔄 Loading YOLOv8m-seg model...
# ...
# ✅ Model loaded successfully
#
# 📊 Training Configuration:
#    Epochs      : 200
#    Image Size  : 640
#    Batch Size  : 8
#    Workers     : 4
#    Device      : GPU (0)
# New https://pypi.org/project/ultralytics/8.4.45 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.43 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA RTX 5000 Ada Generation, 32237MiB)
# ...

# %%
# ==============================
# YOLOv8l SEGMENTATION TRAINING
# ==============================

import os
import torch
from ultralytics import YOLO

print("=" * 60)
print("🚀 YOLOv8l SEGMENTATION TRAINING START")
print("=" * 60)

# ------------------------------
# GPU CHECK
# ------------------------------
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
    print(f"✅ VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    raise RuntimeError("❌ CUDA GPU not available")

# ------------------------------
# PATHS (EDIT IF NEEDED)
# ------------------------------
dataset_path = "/home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml"
output_dir = "/home/ranjan/Documents/yolo26/earlystageapple/Experiment/YOLOv8"

os.makedirs(output_dir, exist_ok=True)

if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"❌ Dataset not found: {dataset_path}")

print(f"✅ Dataset found: {dataset_path}")

# ------------------------------
# LOAD MODEL
# ------------------------------
print("\n🔄 Loading YOLOv8l-seg model...")
model = YOLO("yolov8l-seg.pt")
print("✅ Model loaded successfully")

# ------------------------------
# TRAINING CONFIG
# ------------------------------
EPOCHS = 200
IMGSZ = 640
BATCH = 8   # reduce to 4 if you hit OOM
WORKERS = 4

print("\n📊 Training Configuration:")
print(f"   Epochs      : {EPOCHS}")
print(f"   Image Size  : {IMGSZ}")
print(f"   Batch Size  : {BATCH}")
print(f"   Workers     : {WORKERS}")
print(f"   Device      : GPU (0)")

# ------------------------------
# TRAIN
# ------------------------------
try:
    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=BATCH,
        device=0,              # GPU
        workers=WORKERS,
        
        project=output_dir,
        name="yolov8l_seg_training",
        exist_ok=True,
        
        # training behavior
        pretrained=True,
        optimizer="auto",
        verbose=True,
        seed=42,
        deterministic=False,
        
        # validation + saving
        val=True,
        save=True,
        save_period=10,
        
        # performance
        amp=True,              # mixed precision
        cache=False,           # set True if dataset fits RAM
        
        # logging
        plots=True
    )

    print("\n" + "=" * 60)
    print("✅ TRAINING COMPLETED SUCCESSFULLY")
    print("=" * 60)
    print(f"📁 Results saved at: {output_dir}/yolov8l_seg_training")

# ------------------------------
# FALLBACK (OOM / AMP ISSUES)
# ------------------------------
except Exception as e:
    print("\n❌ Training failed:", e)
    print("\n⚠️ Switching to safe fallback config...")

    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=4,          # safer
        device=0,
        workers=0,        # avoids dataloader issues
        
        project=output_dir,
        name="yolov8l_seg_fallback",
        exist_ok=True,
        
        amp=False,        # disable mixed precision
        val=True,
        save=True
    )

    print("\n✅ Training completed with fallback settings")
# Out:
# ...
# 🚀 YOLOv8l SEGMENTATION TRAINING START
# ...
# ✅ GPU: NVIDIA RTX 5000 Ada Generation
# ✅ VRAM: 33.80 GB
# ✅ Dataset found: /home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml
#
# 🔄 Loading YOLOv8l-seg model...
# ...
# ✅ Model loaded successfully
#
# 📊 Training Configuration:
#    Epochs      : 200
#    Image Size  : 640
#    Batch Size  : 8
#    Workers     : 4
#    Device      : GPU (0)
# New https://pypi.org/project/ultralytics/8.4.45 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.43 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA RTX 5000 Ada Generation, 32237MiB)
# ...

# %%
# ==============================
# YOLOv8x SEGMENTATION TRAINING
# ==============================

import os
import torch
from ultralytics import YOLO

print("=" * 60)
print("🚀 YOLOv8x SEGMENTATION TRAINING START")
print("=" * 60)

# ------------------------------
# GPU CHECK
# ------------------------------
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
    print(f"✅ VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    raise RuntimeError("❌ CUDA GPU not available")

# ------------------------------
# PATHS (EDIT IF NEEDED)
# ------------------------------
dataset_path = "/home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml"
output_dir = "/home/ranjan/Documents/yolo26/earlystageapple/Experiment/YOLOv8"

os.makedirs(output_dir, exist_ok=True)

if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"❌ Dataset not found: {dataset_path}")

print(f"✅ Dataset found: {dataset_path}")

# ------------------------------
# LOAD MODEL
# ------------------------------
print("\n🔄 Loading YOLOv8x-seg model...")
model = YOLO("yolov8x-seg.pt")
print("✅ Model loaded successfully")

# ------------------------------
# TRAINING CONFIG
# ------------------------------
EPOCHS = 200
IMGSZ = 640
BATCH = 8   # reduce to 4 if you hit OOM
WORKERS = 4

print("\n📊 Training Configuration:")
print(f"   Epochs      : {EPOCHS}")
print(f"   Image Size  : {IMGSZ}")
print(f"   Batch Size  : {BATCH}")
print(f"   Workers     : {WORKERS}")
print(f"   Device      : GPU (0)")

# ------------------------------
# TRAIN
# ------------------------------
try:
    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=BATCH,
        device=0,              # GPU
        workers=WORKERS,
        
        project=output_dir,
        name="yolov8x_seg_training",
        exist_ok=True,
        
        # training behavior
        pretrained=True,
        optimizer="auto",
        verbose=True,
        seed=42,
        deterministic=False,
        
        # validation + saving
        val=True,
        save=True,
        save_period=10,
        
        # performance
        amp=True,              # mixed precision
        cache=False,           # set True if dataset fits RAM
        
        # logging
        plots=True
    )

    print("\n" + "=" * 60)
    print("✅ TRAINING COMPLETED SUCCESSFULLY")
    print("=" * 60)
    print(f"📁 Results saved at: {output_dir}/yolov8x_seg_training")

# ------------------------------
# FALLBACK (OOM / AMP ISSUES)
# ------------------------------
except Exception as e:
    print("\n❌ Training failed:", e)
    print("\n⚠️ Switching to safe fallback config...")

    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=4,          # safer
        device=0,
        workers=0,        # avoids dataloader issues
        
        project=output_dir,
        name="yolov8x_seg_fallback",
        exist_ok=True,
        
        amp=False,        # disable mixed precision
        val=True,
        save=True
    )

    print("\n✅ Training completed with fallback settings")
# Out:
# ...
# 🚀 YOLOv8x SEGMENTATION TRAINING START
# ...
# ✅ GPU: NVIDIA RTX 5000 Ada Generation
# ✅ VRAM: 33.80 GB
# ✅ Dataset found: /home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml
#
# 🔄 Loading YOLOv8x-seg model...
# ✅ Model loaded successfully
#
# 📊 Training Configuration:
#    Epochs      : 200
#    Image Size  : 640
#    Batch Size  : 8
#    Workers     : 4
#    Device      : GPU (0)
# New https://pypi.org/project/ultralytics/8.4.45 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.43 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA RTX 5000 Ada Generation, 32237MiB)
# ...

# %%
# ==============================
# YOLOv8n SAHI-READY TRAINING
# ==============================

import os
import torch
from ultralytics import YOLO

print("=" * 60)
print("YOLOv8n SAHI-READY TRAINING (SMALL OBJECT FOCUS)")
print("=" * 60)

# ------------------------------
# GPU SETUP
# ------------------------------
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    device = 0
    print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
    print(f"✅ VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    device = "cpu"
    print("⚠️ No GPU found, using CPU")

# ------------------------------
# PATHS
# ------------------------------
dataset_path = "/home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml"
output_dir = "/home/ranjan/Documents/yolo26/earlystageapple/Experiment/YOLOv8"

os.makedirs(output_dir, exist_ok=True)

if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"❌ Dataset not found: {dataset_path}")

print(f"✅ Dataset found: {dataset_path}")

# ------------------------------
# LOAD MODEL
# ------------------------------
print("\n🔄 Loading YOLOv8n-seg model...")
model = YOLO("yolov8n-seg.pt")
print("✅ Model loaded")

# ------------------------------
# TRAINING CONFIG (SAHI-OPTIMIZED)
# ------------------------------
EPOCHS = 200
IMGSZ = 960          # large resolution helps SAHI slicing
BATCH = 8            # reduce if OOM
WORKERS = 2

print("\n📊 Training Configuration:")
print(f"   Epochs      : {EPOCHS}")
print(f"   Image Size  : {IMGSZ}")
print(f"   Batch Size  : {BATCH}")
print(f"   Workers     : {WORKERS}")
print(f"   Device      : {device}")

# ------------------------------
# TRAIN
# ------------------------------
print("\n🚀 Starting training...\n")

try:
    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=BATCH,
        device=device,
        workers=WORKERS,

        # output
        project=output_dir,
        name="yolov8n_sahi",
        exist_ok=True,

        # training behavior
        pretrained=True,
        optimizer="auto",
        verbose=True,

        # small-object friendly tweaks
        scale=0.5,         # less aggressive scaling
        mosaic=1.0,
        close_mosaic=10,   # stabilize later epochs

        # validation
        val=True,
        save=True,
        save_period=10,

        # performance
        amp=True if device != "cpu" else False,
        cache=False,

        # logging
        plots=True
    )

    print("\n" + "=" * 60)
    print("✅ TRAINING COMPLETED SUCCESSFULLY")
    print("=" * 60)
    print(f"📁 Saved at: {output_dir}/yolov8n_sahi")

# ------------------------------
# FALLBACK (SAFE MODE)
# ------------------------------
except Exception as e:
    print("\n❌ Training failed:", e)
    print("\n⚠️ Switching to safe fallback config...")

    results = model.train(
        data=dataset_path,
        epochs=100,
        imgsz=IMGSZ,
        batch=4,
        device=device,
        workers=0,

        project=output_dir,
        name="yolov8n_sahi_fallback",
        exist_ok=True,

        amp=False,
        val=True,
        save=True
    )

    print("\n✅ Training completed with fallback settings")

print("\n🎯 YOLOv8n SAHI-ready model training complete!")
# Out:
# ...
# YOLOv8n SAHI-READY TRAINING (SMALL OBJECT FOCUS)
# ...
# ✅ GPU: NVIDIA RTX 5000 Ada Generation
# ✅ VRAM: 33.80 GB
# ✅ Dataset found: /home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml
#
# 🔄 Loading YOLOv8n-seg model...
# ✅ Model loaded
#
# 📊 Training Configuration:
#    Epochs      : 200
#    Image Size  : 960
#    Batch Size  : 8
#    Workers     : 2
#    Device      : 0
#
# 🚀 Starting training...
#
# New https://pypi.org/project/ultralytics/8.4.45 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.43 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA RTX 5000 Ada Generation, 32237MiB)
# ...

# %%
# ==============================
# YOLOv8s SAHI-READY TRAINING
# ==============================

import os
import torch
from ultralytics import YOLO

print("=" * 60)
print("YOLOv8s SAHI-READY TRAINING (SMALL OBJECT FOCUS)")
print("=" * 60)

# ------------------------------
# GPU SETUP
# ------------------------------
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    device = 0
    print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
    print(f"✅ VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    device = "cpu"
    print("⚠️ No GPU found, using CPU")

# ------------------------------
# PATHS
# ------------------------------
dataset_path = "/home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml"
output_dir = "/home/ranjan/Documents/yolo26/earlystageapple/Experiment/YOLOv8"

os.makedirs(output_dir, exist_ok=True)

if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"❌ Dataset not found: {dataset_path}")

print(f"✅ Dataset found: {dataset_path}")

# ------------------------------
# LOAD MODEL
# ------------------------------
print("\n🔄 Loading YOLOv8s-seg model...")
model = YOLO("yolov8s-seg.pt")
print("✅ Model loaded")

# ------------------------------
# TRAINING CONFIG (SAHI-OPTIMIZED)
# ------------------------------
EPOCHS = 200
IMGSZ = 960          # large resolution helps SAHI slicing
BATCH = 8            # reduce if OOM
WORKERS = 2

print("\n📊 Training Configuration:")
print(f"   Epochs      : {EPOCHS}")
print(f"   Image Size  : {IMGSZ}")
print(f"   Batch Size  : {BATCH}")
print(f"   Workers     : {WORKERS}")
print(f"   Device      : {device}")

# ------------------------------
# TRAIN
# ------------------------------
print("\n🚀 Starting training...\n")

try:
    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=BATCH,
        device=device,
        workers=WORKERS,

        # output
        project=output_dir,
        name="yolov8s_sahi",
        exist_ok=True,

        # training behavior
        pretrained=True,
        optimizer="auto",
        verbose=True,

        # small-object friendly tweaks
        scale=0.5,         # less aggressive scaling
        mosaic=1.0,
        close_mosaic=10,   # stabilize later epochs

        # validation
        val=True,
        save=True,
        save_period=10,

        # performance
        amp=True if device != "cpu" else False,
        cache=False,

        # logging
        plots=True
    )

    print("\n" + "=" * 60)
    print("✅ TRAINING COMPLETED SUCCESSFULLY")
    print("=" * 60)
    print(f"📁 Saved at: {output_dir}/yolov8s_sahi")

# ------------------------------
# FALLBACK (SAFE MODE)
# ------------------------------
except Exception as e:
    print("\n❌ Training failed:", e)
    print("\n⚠️ Switching to safe fallback config...")

    results = model.train(
        data=dataset_path,
        epochs=100,
        imgsz=IMGSZ,
        batch=4,
        device=device,
        workers=0,

        project=output_dir,
        name="yolov8s_sahi_fallback",
        exist_ok=True,

        amp=False,
        val=True,
        save=True
    )

    print("\n✅ Training completed with fallback settings")

print("\n🎯 YOLOv8s SAHI-ready model training complete!")
# Out:
# ...
# YOLOv8s SAHI-READY TRAINING (SMALL OBJECT FOCUS)
# ...
# ✅ GPU: NVIDIA RTX 5000 Ada Generation
# ✅ VRAM: 33.80 GB
# ✅ Dataset found: /home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml
#
# 🔄 Loading YOLOv8s-seg model...
# ✅ Model loaded
#
# 📊 Training Configuration:
#    Epochs      : 200
#    Image Size  : 960
#    Batch Size  : 8
#    Workers     : 2
#    Device      : 0
#
# 🚀 Starting training...
#
# New https://pypi.org/project/ultralytics/8.4.45 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.43 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA RTX 5000 Ada Generation, 32237MiB)
# ...

# %%
# ==============================
# YOLOv8m SAHI-READY TRAINING
# ==============================

import os
import torch
from ultralytics import YOLO

print("=" * 60)
print("YOLOv8m SAHI-READY TRAINING (SMALL OBJECT FOCUS)")
print("=" * 60)

# ------------------------------
# GPU SETUP
# ------------------------------
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    device = 0
    print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
    print(f"✅ VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    device = "cpu"
    print("⚠️ No GPU found, using CPU")

# ------------------------------
# PATHS
# ------------------------------
dataset_path = "/home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml"
output_dir = "/home/ranjan/Documents/yolo26/earlystageapple/Experiment/YOLOv8"

os.makedirs(output_dir, exist_ok=True)

if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"❌ Dataset not found: {dataset_path}")

print(f"✅ Dataset found: {dataset_path}")

# ------------------------------
# LOAD MODEL
# ------------------------------
print("\n🔄 Loading YOLOv8m-seg model...")
model = YOLO("yolov8m-seg.pt")
print("✅ Model loaded")

# ------------------------------
# TRAINING CONFIG (SAHI-OPTIMIZED)
# ------------------------------
EPOCHS = 200
IMGSZ = 960          # large resolution helps SAHI slicing
BATCH = 8            # reduce if OOM
WORKERS = 2

print("\n📊 Training Configuration:")
print(f"   Epochs      : {EPOCHS}")
print(f"   Image Size  : {IMGSZ}")
print(f"   Batch Size  : {BATCH}")
print(f"   Workers     : {WORKERS}")
print(f"   Device      : {device}")

# ------------------------------
# TRAIN
# ------------------------------
print("\n🚀 Starting training...\n")

try:
    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=BATCH,
        device=device,
        workers=WORKERS,

        # output
        project=output_dir,
        name="yolov8m_sahi",
        exist_ok=True,

        # training behavior
        pretrained=True,
        optimizer="auto",
        verbose=True,

        # small-object friendly tweaks
        scale=0.5,         # less aggressive scaling
        mosaic=1.0,
        close_mosaic=10,   # stabilize later epochs

        # validation
        val=True,
        save=True,
        save_period=10,

        # performance
        amp=True if device != "cpu" else False,
        cache=False,

        # logging
        plots=True
    )

    print("\n" + "=" * 60)
    print("✅ TRAINING COMPLETED SUCCESSFULLY")
    print("=" * 60)
    print(f"📁 Saved at: {output_dir}/yolov8m_sahi")

# ------------------------------
# FALLBACK (SAFE MODE)
# ------------------------------
except Exception as e:
    print("\n❌ Training failed:", e)
    print("\n⚠️ Switching to safe fallback config...")

    results = model.train(
        data=dataset_path,
        epochs=100,
        imgsz=IMGSZ,
        batch=4,
        device=device,
        workers=0,

        project=output_dir,
        name="yolov8m_sahi_fallback",
        exist_ok=True,

        amp=False,
        val=True,
        save=True
    )

    print("\n✅ Training completed with fallback settings")

print("\n🎯 YOLOv8m SAHI-ready model training complete!")
# Out:
# ...
# YOLOv8m SAHI-READY TRAINING (SMALL OBJECT FOCUS)
# ...
# ✅ GPU: NVIDIA RTX 5000 Ada Generation
# ✅ VRAM: 33.80 GB
# ✅ Dataset found: /home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml
#
# 🔄 Loading YOLOv8m-seg model...
# ✅ Model loaded
#
# 📊 Training Configuration:
#    Epochs      : 200
#    Image Size  : 960
#    Batch Size  : 8
#    Workers     : 2
#    Device      : 0
#
# 🚀 Starting training...
#
# New https://pypi.org/project/ultralytics/8.4.45 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.43 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA RTX 5000 Ada Generation, 32237MiB)
# ...

# %%
# ==============================
# YOLOv8l SAHI-READY TRAINING
# ==============================

import os
import torch
from ultralytics import YOLO

print("=" * 60)
print("YOLOv8l SAHI-READY TRAINING (SMALL OBJECT FOCUS)")
print("=" * 60)

# ------------------------------
# GPU SETUP
# ------------------------------
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    device = 0
    print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
    print(f"✅ VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    device = "cpu"
    print("⚠️ No GPU found, using CPU")

# ------------------------------
# PATHS
# ------------------------------
dataset_path = "/home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml"
output_dir = "/home/ranjan/Documents/yolo26/earlystageapple/Experiment/YOLOv8"

os.makedirs(output_dir, exist_ok=True)

if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"❌ Dataset not found: {dataset_path}")

print(f"✅ Dataset found: {dataset_path}")

# ------------------------------
# LOAD MODEL
# ------------------------------
print("\n🔄 Loading YOLOv8l-seg model...")
model = YOLO("yolov8l-seg.pt")
print("✅ Model loaded")

# ------------------------------
# TRAINING CONFIG (SAHI-OPTIMIZED)
# ------------------------------
EPOCHS = 200
IMGSZ = 960          # large resolution helps SAHI slicing
BATCH = 8            # reduce if OOM
WORKERS = 2

print("\n📊 Training Configuration:")
print(f"   Epochs      : {EPOCHS}")
print(f"   Image Size  : {IMGSZ}")
print(f"   Batch Size  : {BATCH}")
print(f"   Workers     : {WORKERS}")
print(f"   Device      : {device}")

# ------------------------------
# TRAIN
# ------------------------------
print("\n🚀 Starting training...\n")

try:
    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=BATCH,
        device=device,
        workers=WORKERS,

        # output
        project=output_dir,
        name="yolov8l_sahi",
        exist_ok=True,

        # training behavior
        pretrained=True,
        optimizer="auto",
        verbose=True,

        # small-object friendly tweaks
        scale=0.5,         # less aggressive scaling
        mosaic=1.0,
        close_mosaic=10,   # stabilize later epochs

        # validation
        val=True,
        save=True,
        save_period=10,

        # performance
        amp=True if device != "cpu" else False,
        cache=False,

        # logging
        plots=True
    )

    print("\n" + "=" * 60)
    print("✅ TRAINING COMPLETED SUCCESSFULLY")
    print("=" * 60)
    print(f"📁 Saved at: {output_dir}/yolov8l_sahi")

# ------------------------------
# FALLBACK (SAFE MODE)
# ------------------------------
except Exception as e:
    print("\n❌ Training failed:", e)
    print("\n⚠️ Switching to safe fallback config...")

    results = model.train(
        data=dataset_path,
        epochs=100,
        imgsz=IMGSZ,
        batch=4,
        device=device,
        workers=0,

        project=output_dir,
        name="yolov8l_sahi_fallback",
        exist_ok=True,

        amp=False,
        val=True,
        save=True
    )

    print("\n✅ Training completed with fallback settings")

print("\n🎯 YOLOv8l SAHI-ready model training complete!")
# Out:
# ...
# YOLOv8l SAHI-READY TRAINING (SMALL OBJECT FOCUS)
# ...
# ✅ GPU: NVIDIA RTX 5000 Ada Generation
# ✅ VRAM: 33.80 GB
# ✅ Dataset found: /home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml
#
# 🔄 Loading YOLOv8l-seg model...
# ✅ Model loaded
#
# 📊 Training Configuration:
#    Epochs      : 200
#    Image Size  : 960
#    Batch Size  : 8
#    Workers     : 2
#    Device      : 0
#
# 🚀 Starting training...
#
# New https://pypi.org/project/ultralytics/8.4.45 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.43 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA RTX 5000 Ada Generation, 32237MiB)
# ...

# %%
# ==============================
# YOLOv8x SAHI-READY TRAINING
# ==============================

import os
import torch
from ultralytics import YOLO

print("=" * 60)
print("YOLOv8l SAHI-READY TRAINING (SMALL OBJECT FOCUS)")
print("=" * 60)

# ------------------------------
# GPU SETUP
# ------------------------------
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    device = 0
    print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
    print(f"✅ VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    device = "cpu"
    print("⚠️ No GPU found, using CPU")

# ------------------------------
# PATHS
# ------------------------------
dataset_path = "/home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml"
output_dir = "/home/ranjan/Documents/yolo26/earlystageapple/Experiment/YOLOv8"

os.makedirs(output_dir, exist_ok=True)

if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"❌ Dataset not found: {dataset_path}")

print(f"✅ Dataset found: {dataset_path}")

# ------------------------------
# LOAD MODEL
# ------------------------------
print("\n🔄 Loading YOLOv8x-seg model...")
model = YOLO("yolov8x-seg.pt")
print("✅ Model loaded")

# ------------------------------
# TRAINING CONFIG (SAHI-OPTIMIZED)
# ------------------------------
EPOCHS = 200
IMGSZ = 960          # large resolution helps SAHI slicing
BATCH = 8            # reduce if OOM
WORKERS = 2

print("\n📊 Training Configuration:")
print(f"   Epochs      : {EPOCHS}")
print(f"   Image Size  : {IMGSZ}")
print(f"   Batch Size  : {BATCH}")
print(f"   Workers     : {WORKERS}")
print(f"   Device      : {device}")

# ------------------------------
# TRAIN
# ------------------------------
print("\n🚀 Starting training...\n")

try:
    results = model.train(
        data=dataset_path,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=BATCH,
        device=device,
        workers=WORKERS,

        # output
        project=output_dir,
        name="yolov8x_sahi",
        exist_ok=True,

        # training behavior
        pretrained=True,
        optimizer="auto",
        verbose=True,

        # small-object friendly tweaks
        scale=0.5,         # less aggressive scaling
        mosaic=1.0,
        close_mosaic=10,   # stabilize later epochs

        # validation
        val=True,
        save=True,
        save_period=10,

        # performance
        amp=True if device != "cpu" else False,
        cache=False,

        # logging
        plots=True
    )

    print("\n" + "=" * 60)
    print("✅ TRAINING COMPLETED SUCCESSFULLY")
    print("=" * 60)
    print(f"📁 Saved at: {output_dir}/yolov8x_sahi")

# ------------------------------
# FALLBACK (SAFE MODE)
# ------------------------------
except Exception as e:
    print("\n❌ Training failed:", e)
    print("\n⚠️ Switching to safe fallback config...")

    results = model.train(
        data=dataset_path,
        epochs=100,
        imgsz=IMGSZ,
        batch=4,
        device=device,
        workers=0,

        project=output_dir,
        name="yolov8x_sahi_fallback",
        exist_ok=True,

        amp=False,
        val=True,
        save=True
    )

    print("\n✅ Training completed with fallback settings")

print("\n🎯 YOLOv8x SAHI-ready model training complete!")
# Out:
# ...
# YOLOv8l SAHI-READY TRAINING (SMALL OBJECT FOCUS)
# ...
# ✅ GPU: NVIDIA RTX 5000 Ada Generation
# ✅ VRAM: 33.80 GB
# ✅ Dataset found: /home/ranjan/Documents/yolo26/earlystageapple/GreenApples.v4-yolo26smallobjectsegmentation.yolo26/data.yaml
#
# 🔄 Loading YOLOv8x-seg model...
# ✅ Model loaded
#
# 📊 Training Configuration:
#    Epochs      : 200
#    Image Size  : 960
#    Batch Size  : 8
#    Workers     : 2
#    Device      : 0
#
# 🚀 Starting training...
#
# New https://pypi.org/project/ultralytics/8.4.45 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.43 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA RTX 5000 Ada Generation, 32237MiB)
# ...

# %%
import os
import torch
from ultralytics import YOLO
from pathlib import Path
import cv2

# Simple version using Ultralytics plotting
model_path = '/home/ranjan/Documents/yolo26/earlystageapple/Experiment/YOLOv8/YOLOv8seg-SAHI/yolov8n_sahi/weights/best.pt'
input_dir = '/home/ranjan/Documents/yolo26/earlystageapple/Experiment/Images/RGB'
output_dir = '/home/ranjan/Documents/yolo26/earlystageapple/Experiment/Images/yolov8n/YOLOv8sahi'

os.makedirs(output_dir, exist_ok=True)

# Load model
model = YOLO(model_path)

# Get all images
image_files = []
for ext in ['.jpg', '.jpeg', '.png', '.bmp', '.tiff']:
    image_files.extend(Path(input_dir).glob(f'*{ext}'))
    image_files.extend(Path(input_dir).glob(f'*{ext.upper()}'))

print(f"Found {len(image_files)} images")

# Process each image
for img_path in image_files:
    # Run inference
    results = model(str(img_path), save=False, verbose=False)
    
    # Save visualized result
    for result in results:
        # Save with Ultralytics plotting (includes masks and boxes)
        plotted = result.plot()  # This creates the visualization
        
        # Save to output directory
        output_path = os.path.join(output_dir, f"result_{img_path.name}")
        cv2.imwrite(output_path, plotted)
        
        # Also save the raw masks if needed
        if result.masks is not None:
            # Create mask-only image
            h, w = plotted.shape[:2]
            mask_img = np.zeros((h, w, 3), dtype=np.uint8)
            
            masks = result.masks.data.cpu().numpy() if result.masks.data.is_cuda else result.masks.data.numpy()
            for mask in masks:
                mask_resized = cv2.resize(mask, (w, h))
                mask_binary = (mask_resized > 0.5).astype(np.uint8)
                mask_img[mask_binary == 1] = (0, 255, 0)  # Green masks
            
            mask_path = os.path.join(output_dir, f"mask_{img_path.name}")
            cv2.imwrite(mask_path, mask_img)

print(f"Results saved to: {output_dir}")
# Out:
# Found 55 images
# Results saved to: /home/ranjan/Documents/yolo26/earlystageapple/Experiment/Images/yolov8n/YOLOv8sahi
